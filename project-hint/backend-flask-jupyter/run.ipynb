# %%
# !python app.py
# Out:
# 설정파일 위치:  /opt/homebrew/Caskroom/miniforge/base/envs/hint/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc
# /Users/hwaner/.matplotlib
#  * Serving Flask app 'app'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5050
#  * Running on http://192.168.123.17:5050
# Press CTRL+C to quit
#  * Restarting with stat
# 설정파일 위치:  /opt/homebrew/Caskroom/miniforge/base/envs/hint/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc
# /Users/hwaner/.matplotlib
#  * Debugger is active!
#  * Debugger PIN: 757-719-408
# 127.0.0.1 - - [17/Oct/2022 17:41:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Oct/2022 17:41:50] "GET /static/vendors/bootstrap/dist/css/bootstrap.min.css HTTP/1.1" 304 -
# 127.0.0.1 - - [17/Oct/2022 17:41:50] "GET /static/vendors/iCheck/skins/flat/green.css HTTP/1.1" 304 -
# ...
